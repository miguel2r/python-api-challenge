# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import json
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import gmaps.datasets
# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# Study data files
city_f = "cities_df.csv"

# Read the mouse data 
city_df = pd.read_csv(city_f)
city_df
# Out:
#             Cityv  Cloudiness Countryv       Datev  Humidity  Latitude  \
# 0         Ushuaia          90       AR  1585553473        70    -54.80
# 1    Punta Arenas          40       CL  1585553383        70    -53.15
# 2            Okha           0       RU  1585553473        94     53.57
# 3         Mimongo          33       GA  1585553473        51     -1.62
# 4         Qaanaaq          20       GL  1585553474        84     77.48
# ..            ...         ...      ...         ...       ...       ...
# 566         Yanam           0       IN  1585553607        32     16.73
# 567        Nabire          98       ID  1585553607        86     -3.37
# 568       Jiuquan          13       CN  1585553607        24     39.74
# 569    Skibbereen          20       IE  1585553607        71     51.55
# 570       Mordovo         100       RU  1585553607        47     52.08
#
#      Longitude  MaxTemp  WindSpeed    StdDate    Mt_F  tmp_C
# ...

# %%
#MM
#import gmaps
#import gmaps.datasets

gmaps.configure(g_key) # Fill in with your API key

earthquake_df = gmaps.datasets.load_dataset_as_df('earthquakes')
earthquake_df.head()
# Out:
#     latitude   longitude  magnitude
# 0  65.193300 -149.072500       1.70
# 1  38.791832 -122.780830       2.10
# 2  38.818001 -122.792168       0.48
# 3  33.601667 -116.727667       0.78
# 4  37.378334 -118.520836       3.64

# %%
#MM

locations = earthquake_df[['latitude', 'longitude']]
weights = earthquake_df['magnitude']
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
locations = city_df[['Latitude', 'Longitude']]
weights = city_df['Humidity']
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#mm
city_df
# Out:
#             Cityv  Cloudiness Countryv       Datev  Humidity  Latitude  \
# 0         Ushuaia          90       AR  1585553473        70    -54.80
# 1    Punta Arenas          40       CL  1585553383        70    -53.15
# 2            Okha           0       RU  1585553473        94     53.57
# 3         Mimongo          33       GA  1585553473        51     -1.62
# 4         Qaanaaq          20       GL  1585553474        84     77.48
# ..            ...         ...      ...         ...       ...       ...
# 566         Yanam           0       IN  1585553607        32     16.73
# 567        Nabire          98       ID  1585553607        86     -3.37
# 568       Jiuquan          13       CN  1585553607        24     39.74
# 569    Skibbereen          20       IE  1585553607        71     51.55
# 570       Mordovo         100       RU  1585553607        47     52.08
#
#      Longitude  MaxTemp  WindSpeed    StdDate    Mt_F  tmp_C
# ...

# %%
# fitting wheather conditions
city_df
max_temp_low = 80
min_temp_bigger = 70
windspeed = 11
clodinessx =0
# ====
Humidityx =81

city_res_df=city_df.loc[(city_df['tmp_C'] <= max_temp_low)    & (city_df['WindSpeed'] <= windspeed ) &
                        (city_df['Cloudiness'] == clodinessx )& (city_df['Humidity'] == Humidityx)]
                 
    
city_res_df

#A max temperature lower than 80 degrees but higher than 70.
#Wind speed less than 10 mph.
#Zero cloudiness.
# Out:
#            Cityv  Cloudiness Countryv       Datev  Humidity  Latitude  \
# 22       Mataura           0       NZ  1585553477        81    -46.19
# 543  Kostomuksha           0       RU  1585553598        81     64.57
#
#      Longitude  MaxTemp  WindSpeed    StdDate    Mt_F  tmp_C
# 22      168.86   288.15       1.79  3/30/2020  50.954  15.00
# 543      30.58   269.61       4.92  3/30/2020  50.954  -3.54

# %%
locations = city_res_df[['Latitude', 'Longitude']]
weights = city_res_df['Humidity']
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
##mm
# geocoordinates
target_coordinates = "43.6187102, -116.2146068"
target_search = "Chinese"
target_radius = 8000
target_type = "restaurant"
print(target_coordinates)
# Out:
# 43.6187102, -116.2146068

# %%
# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}
# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
#mm
print(response.url)
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=43.6187102%2C+-116.2146068&keyword=Chinese&radius=8000&type=restaurant&key=AIzaSyBrD11TW3S_bFESn5G5IIKjsWJirRs0-II

# %%
#mm convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CrQCKAEAAJM7XcRh6ZE3-V71lp7zsVP1eh7pUhYtSMXvlY49ITCjhN16nhASMH7pQ1WHQAY406NhjVRGhxMEvYA3Duj_dETpXNllutXQuvddOz0rqcsMeOrNl4MkWEoZiofBqFIOp8qxDKwHetBFJ45j5t_fD8ICWYlGO9JKtu2NWtCx13nLDVNff8QqnR6b2OgqVsTkh3bdpXFZ9u-AQIM3YnkDdDbFo2yDsBbEgKDs95wm5IRQWuwtfl55XbXnbI8cLtRuaIcyrsCMd2Ov8gr9bJjY6nEbj8scJ-fF81MzPLoyM5hoG9Oh4qsZvIoVKdIkiwuKWwjwqrIE8F7NDgHMfEDdy2FETKJgL-U5YAFCN6qtZlrH0VvMNt_MzLs4JGsoB-GJEWY6okK-LoPuL1sXdF13wvcSEC1MDGGw4AofO4yJnbd95rAaFMflUSxKK-6CL_45MZErdt6lEtW1",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 43.6487196,
#                     "lng": -116.246199
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.65013982989272,
#                         "lng": -116.2449386701073
#                     },
#                     "southwest": {
# ...

# %%
# mmPrint the name and address of the first restaurant that appears
print(places_data["results"][0]["name"])
print(places_data["results"][0]["vicinity"])
# Out:
# New Garden Chinese Restaurant
# 4624 W State St, Boise

# %%
##mm
city_res_df.head(5)
# Out:
#            Cityv  Cloudiness Countryv       Datev  Humidity  Latitude  \
# 22       Mataura           0       NZ  1585553477        81    -46.19
# 543  Kostomuksha           0       RU  1585553598        81     64.57
#
#      Longitude  MaxTemp  WindSpeed    StdDate    Mt_F  tmp_C
# 22      168.86   288.15       1.79  3/30/2020  50.954  15.00
# 543      30.58   269.61       4.92  3/30/2020  50.954  -3.54

# %%
##mm
#for  row in city_res_df:
#v_lat
v_lat=city_res_df['Latitude']
v_lon =city_res_df['Longitude']
vlat = v_lat.to_list()
vlon = v_lon.to_list()
for i in range(len(v_lat)): 
    
    location = str(vlat[i]) + ',' + str(vlon[i])
    #print(vlat[i],vlon[i]," i",i)
    print(location)
# Out:
# -46.19,168.86
# 64.57,30.58

# %%
#Store into variable named hotel_df.
#Add a "Hotel Name" column to the DataFrame.
#Set parameters to search for hotels with 5000 meters.
#Hit the Google Places API for each city's coordinates.
#Store the first Hotel result into the DataFrame.
#Plot markers on top of the heatmap.
#v_cities =city_res_df['Latitude']


    
v_lat=city_res_df['Latitude']
v_lon =city_res_df['Longitude']
vlat = v_lat.to_list()
vlon = v_lon.to_list()

hot_name= []
vecinity = []
Latitude = []
Longitude= []
v_count=0
#Countryv= []
#Datev=[]

#keyword = "Chinese"
radius =5000
type = "lodging"

for i in range(len(v_lat)):
     try:
        v_lat =vlat[i]
        v_lon =vlon[i]
        location = str(vlat[i]) + ',' + str(vlon[i])
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
        # loop through google map data , make requests and parse
        print ('Beginning Data Retrieval')    
        print  ('-----------------------------')

        base_url = ('https://maps.googleapis.com/maps/api/place/nearbysearch/json''?location=%s' #'&keyword=%s'
                   '&rankBy=distance&radius=%s''&type=%s''&key=%s') % (location #, keyword
                                                                  , radius,type, g_key)
        response = requests.get(base_url).json()
        hot_name.append(response["results"][0]["name"])
        vecinity.append(response["results"][0]["vicinity"])
        Latitude.append(response["results"][0]['geometry']['location']['lat'])
        Longitude.append(response["results"][0]['geometry']['location']['lng'])
   
        #print(base_url)
        #print(json.dumps(response, indent=4, sort_keys=True))
        print('Processing Record',v_count)
    except:
        print("City not found",v_city)
     pass
    
        print ('Ending Data Retrieval')    
        print  ('-----------------------------')
# Out:
#   File "<tokenize>", line 50
#     except:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
#creating a  dataframe
v_city_dfx = pd.DataFrame({
    "hot_name": hot_name ,
    "vecinity": vecinity ,
  #  "Countryv": Countryv,
  #  "Datev": Datev,
  #  "Humidity": Humidity,
    "Latitude": Latitude ,
    "Longitude": Longitude #,
  #  "MaxTemp": MaxTemp,
  #  "Cloudiness": Cloudiness,
  #  "WindSpeed": WindSpeed,
  #  "StdDate":Datec,
  #  "Mt_F":Mtemp
    
})

v_city_dfx
# Out:
#                   hot_name                           vecinity   Latitude  \
# 0            Ellie's Villa             15 Dunns Road, Mataura -46.201943
# 1  Apartments on Lenina 17  Ulitsa Lenina, д. 17, Kostomuksha  64.587408
#
#     Longitude
# 0  168.855043
# 1   30.605944

# %%
#Mix 2 maps
locations = city_res_df[['Latitude', 'Longitude']]
weights = city_res_df['Humidity']
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig


hlocations = v_city_dfx[['Latitude', 'Longitude']]
info_box_contentx = v_city_dfx['hot_name']
#fig = gmaps.figure()
markers = gmaps.marker_layer(hlocations,info_box_content=info_box_contentx)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
 # Print the name and address of the first restaurant that appears
print(response["results"][0]["name"])
print(response["results"][0]["vicinity"])
# Out:
# Ot Dyadi Fodora
# Ulitsa Antikaynena, 25А, Kostomuksha

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-278-f8dffc31712f> in <module>
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#
# NameError: name 'narrowed_city_df' is not defined

# %%
# Add marker layer ontop of heat map


# Display Map
